# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
#cities = []
units = "imperial" #default to kelvin if you dont assign the units to celcius or degrees

# Build query URL


record_count = 1
set_count = 1 

# Get weather data
for i, city in enumerate(cities):
    if (i%50 == 0 & i >= 50):
        set_count+=1
        record_count= 0
    
    queryURL = f"{url}appid={api_key}&units={units}&q={city}"  
   # print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
   # record_count+=1
    time.sleep(1)
    try:
        weatherResponse = requests.get(queryURL)
        weatherJSON = weatherResponse.json()
        
        name =  weatherJSON['name']
        lat =  weatherJSON['coord']['lat']
        lng =  weatherJSON['coord']['lon']
        maxtempFs =  weatherJSON['main']['temp_max']
        humidity = weatherJSON['main']['humidity']
        Cloudiness = weatherJSON['clouds']['all']
        Wind_Speed = weatherJSON['wind']['speed']
        Country = weatherJSON['sys']['country']
        date = weatherJSON['dt']
        
        
        cities.append({
            "City": name,
            "Lat": lat,
            "Lng" : lng,
            "Max Temp" :  maxtempFs,
            "Humidity" : humidity,
            "Cloudiness" : Cloudiness,
            "Wind Speed" :  Wind_Speed,
            "Date"       :  date
            
        })
        
        print("Processing Record %s of Set %s | %s" %(record_count, set_count, city))
        record_count+=1
        
    except (KeyError, IndexError):
         print("City not found... skipping.")
    
    #pprint(weatherJSON)
#     time.sleep(1)
   #city.append(weatherJSON['name' or 'city']) whatever prints out in json()
#      for i in range((cities), 50):            
  # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
#     try:
#         cities =  weatherJSON["results"][0]["name"]
#         print(f"Processing Record {i} of Set 1 | {cities[i]}")
        
#     except (KeyError, IndexError):
#         print("City not found... skipping.")
 
    #print(f"Processing Record {i} of Set 1 | {cities[i]}")
# Out:
# Processing Record 1 of Set 1 | nueva loja
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | arlit
# Processing Record 4 of Set 1 | ushtobe
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | aklavik
# City not found... skipping.
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | darhan
# Processing Record 9 of Set 1 | touros
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | coihaique
# Processing Record 12 of Set 1 | iznoski
# Processing Record 13 of Set 1 | tautira
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | samarai
# Processing Record 18 of Set 1 | zacatepec
# Processing Record 19 of Set 1 | saldanha
# Processing Record 20 of Set 1 | leningradskiy
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | maragogi
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | severo-kurilsk
# Processing Record 28 of Set 1 | havelock
# Processing Record 29 of Set 1 | te anau
# City not found... skipping.
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | bandarbeyla
# Processing Record 33 of Set 1 | faya
# Processing Record 34 of Set 1 | quiindy
# Processing Record 35 of Set 1 | carutapera
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | portland
# Processing Record 38 of Set 1 | miles city
# City not found... skipping.
# City not found... skipping.
# Processing Record 39 of Set 1 | walvis bay
# City not found... skipping.
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | olinda
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | lavrentiya
# Processing Record 51 of Set 1 | coahuayana
# Processing Record 52 of Set 1 | kaitangata
# City not found... skipping.
# Processing Record 53 of Set 1 | hilo
# Processing Record 54 of Set 1 | san patricio
# Processing Record 55 of Set 1 | saint-leu
# Processing Record 56 of Set 1 | ndele
# Processing Record 57 of Set 1 | port blair
# Processing Record 58 of Set 1 | new norfolk
# Processing Record 59 of Set 1 | lebu
# Processing Record 60 of Set 1 | kibaya
# Processing Record 61 of Set 1 | hasaki
# Processing Record 62 of Set 1 | orlik
# Processing Record 63 of Set 1 | saint-philippe
# Processing Record 64 of Set 1 | upernavik
# Processing Record 65 of Set 1 | svetlaya
# Processing Record 66 of Set 1 | khatanga
# Processing Record 67 of Set 1 | bethel
# Processing Record 68 of Set 1 | pandan
# Processing Record 69 of Set 1 | sao gabriel da cachoeira
# Processing Record 70 of Set 1 | tupik
# Processing Record 71 of Set 1 | atuona
# Processing Record 72 of Set 1 | armidale
# City not found... skipping.
# Processing Record 73 of Set 1 | galveston
# Processing Record 74 of Set 1 | cape town
# Processing Record 75 of Set 1 | alofi
# City not found... skipping.
# City not found... skipping.
# Processing Record 76 of Set 1 | jamestown
# Processing Record 77 of Set 1 | ivanovka
# Processing Record 78 of Set 1 | plettenberg bay
# Processing Record 79 of Set 1 | annaka
# Processing Record 80 of Set 1 | pisco
# Processing Record 81 of Set 1 | ostrovnoy
# City not found... skipping.
# Processing Record 82 of Set 1 | norman wells
# Processing Record 83 of Set 1 | hermanus
# Processing Record 84 of Set 1 | jiayuguan
# Processing Record 85 of Set 1 | provideniya
# City not found... skipping.
# Processing Record 86 of Set 1 | kavaratti
# Processing Record 87 of Set 1 | tuatapere
# Processing Record 88 of Set 1 | castro
# Processing Record 89 of Set 1 | geraldton
# City not found... skipping.
# Processing Record 90 of Set 1 | pilar
# Processing Record 91 of Set 1 | baykit
# Processing Record 92 of Set 1 | bengkulu
# Processing Record 93 of Set 1 | coquimbo
# Processing Record 94 of Set 1 | burnie
# Processing Record 95 of Set 1 | isiro
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# Processing Record 96 of Set 1 | artyom
# Processing Record 97 of Set 1 | schifferstadt
# Processing Record 98 of Set 1 | centenario do sul
# Processing Record 99 of Set 1 | east london
# Processing Record 100 of Set 1 | chenghai
# Processing Record 101 of Set 1 | starovelichkovskaya
# Processing Record 102 of Set 1 | christchurch
# Processing Record 103 of Set 1 | dapaong
# Processing Record 104 of Set 1 | ayagoz
# City not found... skipping.
# Processing Record 105 of Set 1 | salinas
# Processing Record 106 of Set 1 | saskylakh
# Processing Record 107 of Set 1 | thompson
# Processing Record 108 of Set 1 | torbay
# Processing Record 109 of Set 1 | quatre cocos
# Processing Record 110 of Set 1 | hobart
# Processing Record 111 of Set 1 | salinopolis
# City not found... skipping.
# Processing Record 112 of Set 1 | port hawkesbury
# Processing Record 113 of Set 1 | port elizabeth
# Processing Record 114 of Set 1 | wahiawa
# Processing Record 115 of Set 1 | broken hill
# Processing Record 116 of Set 1 | qaanaaq
# Processing Record 117 of Set 1 | kokopo
# Processing Record 118 of Set 1 | santa marta
# Processing Record 119 of Set 1 | fortuna
# Processing Record 120 of Set 1 | bousse
# Processing Record 121 of Set 1 | grand gaube
# Processing Record 122 of Set 1 | bubaque
# Processing Record 123 of Set 1 | tapes
# Processing Record 124 of Set 1 | roquetas de mar
# Processing Record 125 of Set 1 | bambous virieux
# Processing Record 126 of Set 1 | dospat
# Processing Record 127 of Set 1 | sakakah
# Processing Record 128 of Set 1 | kibala
# City not found... skipping.
# Processing Record 129 of Set 1 | kenai
# Processing Record 130 of Set 1 | gladstone
# Processing Record 131 of Set 1 | rocha
# Processing Record 132 of Set 1 | clyde river
# Processing Record 133 of Set 1 | acapulco
# Processing Record 134 of Set 1 | nemuro
# Processing Record 135 of Set 1 | tasiilaq
# Processing Record 136 of Set 1 | narsaq
# Processing Record 137 of Set 1 | kavieng
# Processing Record 138 of Set 1 | ludvika
# Processing Record 139 of Set 1 | saint george
# Processing Record 140 of Set 1 | bahia de caraquez
# Processing Record 141 of Set 1 | batemans bay
# Processing Record 142 of Set 1 | puerto colombia
# Processing Record 143 of Set 1 | yekaterinoslavka
# Processing Record 144 of Set 1 | mecca
# Processing Record 145 of Set 1 | derzhavinsk
# Processing Record 146 of Set 1 | tiksi
# Processing Record 147 of Set 1 | san cristobal
# Processing Record 148 of Set 1 | mnogovershinnyy
# Processing Record 149 of Set 1 | alice springs
# Processing Record 150 of Set 1 | eureka
# Processing Record 151 of Set 1 | isangel
# Processing Record 152 of Set 1 | ngunguru
# Processing Record 153 of Set 1 | inhambane
# Processing Record 154 of Set 1 | victoria
# Processing Record 155 of Set 1 | myaundzha
# Processing Record 156 of Set 1 | avera
# Processing Record 157 of Set 1 | areosa
# Processing Record 158 of Set 1 | neuquen
# Processing Record 159 of Set 1 | mehamn
# Processing Record 160 of Set 1 | washington
# Processing Record 161 of Set 1 | vernon
# Processing Record 162 of Set 1 | ruteng
# Processing Record 163 of Set 1 | jalpan
# Processing Record 164 of Set 1 | samagaltay
# Processing Record 165 of Set 1 | bela cruz
# City not found... skipping.
# Processing Record 166 of Set 1 | muros
# Processing Record 167 of Set 1 | iqaluit
# City not found... skipping.
# Processing Record 168 of Set 1 | fort nelson
# Processing Record 169 of Set 1 | turukhansk
# Processing Record 170 of Set 1 | yerbogachen
# Processing Record 171 of Set 1 | plymouth
# Processing Record 172 of Set 1 | souillac
# Processing Record 173 of Set 1 | college
# Processing Record 174 of Set 1 | deputatskiy
# Processing Record 175 of Set 1 | ilhabela
# Processing Record 176 of Set 1 | tual
# Processing Record 177 of Set 1 | tura
# Processing Record 178 of Set 1 | jalu
# Processing Record 179 of Set 1 | belmonte
# Processing Record 180 of Set 1 | kimbe
# Processing Record 181 of Set 1 | santa maria
# Processing Record 182 of Set 1 | el alto
# Processing Record 183 of Set 1 | peace river
# Processing Record 184 of Set 1 | izyum
# Processing Record 185 of Set 1 | frontera
# Processing Record 186 of Set 1 | san vicente
# Processing Record 187 of Set 1 | worthington
# Processing Record 188 of Set 1 | richards bay
# Processing Record 189 of Set 1 | sorong
# Processing Record 190 of Set 1 | pevek
# Processing Record 191 of Set 1 | tucumcari
# Processing Record 192 of Set 1 | sao filipe
# Processing Record 193 of Set 1 | port lincoln
# Processing Record 194 of Set 1 | kindu
# Processing Record 195 of Set 1 | cabedelo
# Processing Record 196 of Set 1 | salalah
# Processing Record 197 of Set 1 | trairi
# Processing Record 198 of Set 1 | port said
# Processing Record 199 of Set 1 | kotka
# Processing Record 200 of Set 1 | rajmahal
# Processing Record 201 of Set 1 | ancud
# Processing Record 202 of Set 1 | kudahuvadhoo
# Processing Record 203 of Set 1 | salekhard
# Processing Record 204 of Set 1 | chokurdakh
# Processing Record 205 of Set 1 | esik
# Processing Record 206 of Set 1 | virginia beach
# Processing Record 207 of Set 1 | tuktoyaktuk
# Processing Record 208 of Set 1 | grindavik
# Processing Record 209 of Set 1 | chazuta
# Processing Record 210 of Set 1 | sabang
# Processing Record 211 of Set 1 | piacabucu
# Processing Record 212 of Set 1 | chuy
# Processing Record 213 of Set 1 | tessalit
# Processing Record 214 of Set 1 | sabha
# Processing Record 215 of Set 1 | los llanos de aridane
# City not found... skipping.
# Processing Record 216 of Set 1 | olhao
# Processing Record 217 of Set 1 | camargo
# Processing Record 218 of Set 1 | ca mau
# Processing Record 219 of Set 1 | faanui
# Processing Record 220 of Set 1 | forbes
# Processing Record 221 of Set 1 | sambava
# Processing Record 222 of Set 1 | puro
# Processing Record 223 of Set 1 | san quintin
# Processing Record 224 of Set 1 | maniitsoq
# Processing Record 225 of Set 1 | palmer
# Processing Record 226 of Set 1 | sinnamary
# Processing Record 227 of Set 1 | longyearbyen
# Processing Record 228 of Set 1 | seminole
# Processing Record 229 of Set 1 | husavik
# Processing Record 230 of Set 1 | agadir
# Processing Record 231 of Set 1 | praia da vitoria
# Processing Record 232 of Set 1 | pundaguitan
# Processing Record 233 of Set 1 | lamu
# Processing Record 234 of Set 1 | yingcheng
# Processing Record 235 of Set 1 | kut chap
# Processing Record 236 of Set 1 | fairbanks
# Processing Record 237 of Set 1 | vrangel
# Processing Record 238 of Set 1 | kruisfontein
# Processing Record 239 of Set 1 | chimoio
# Processing Record 240 of Set 1 | cherskiy
# Processing Record 241 of Set 1 | sitka
# Processing Record 242 of Set 1 | kiama
# Processing Record 243 of Set 1 | port macquarie
# Processing Record 244 of Set 1 | arraial do cabo
# Processing Record 245 of Set 1 | avarua
# Processing Record 246 of Set 1 | cabo san lucas
# Processing Record 247 of Set 1 | trincomalee
# Processing Record 248 of Set 1 | antsohihy
# Processing Record 249 of Set 1 | sangar
# Processing Record 250 of Set 1 | san andres
# City not found... skipping.
# Processing Record 251 of Set 1 | gatton
# Processing Record 252 of Set 1 | vao
# Processing Record 253 of Set 1 | bocas del toro
# Processing Record 254 of Set 1 | tazovskiy
# Processing Record 255 of Set 1 | manicore
# Processing Record 256 of Set 1 | corovode
# Processing Record 257 of Set 1 | batagay
# Processing Record 258 of Set 1 | vestmannaeyjar
# Processing Record 259 of Set 1 | ilulissat
# Processing Record 260 of Set 1 | loma de gato
# Processing Record 261 of Set 1 | sayyan
# Processing Record 262 of Set 1 | okha
# Processing Record 263 of Set 1 | yei
# Processing Record 264 of Set 1 | high level
# Processing Record 265 of Set 1 | tubuala
# Processing Record 266 of Set 1 | broome
# City not found... skipping.
# Processing Record 267 of Set 1 | eyl
# Processing Record 268 of Set 1 | ewa beach
# Processing Record 269 of Set 1 | sao joao da barra
# Processing Record 270 of Set 1 | abu samrah
# Processing Record 271 of Set 1 | sovetsk
# Processing Record 272 of Set 1 | rhyl
# Processing Record 273 of Set 1 | rabo de peixe
# Processing Record 274 of Set 1 | roald
# Processing Record 275 of Set 1 | kahului
# City not found... skipping.
# Processing Record 276 of Set 1 | nikolskoye
# Processing Record 277 of Set 1 | etchoropo
# Processing Record 278 of Set 1 | constitucion
# Processing Record 279 of Set 1 | san jeronimo
# Processing Record 280 of Set 1 | howard springs
# Processing Record 281 of Set 1 | kandrian
# Processing Record 282 of Set 1 | wittmund
# Processing Record 283 of Set 1 | kodiak
# Processing Record 284 of Set 1 | sioux falls
# Processing Record 285 of Set 1 | asau
# Processing Record 286 of Set 1 | talnakh
# Processing Record 287 of Set 1 | vila
# Processing Record 288 of Set 1 | charlestown
# Processing Record 289 of Set 1 | airai
# Processing Record 290 of Set 1 | huarmey
# City not found... skipping.
# Processing Record 291 of Set 1 | nanfeng
# Processing Record 292 of Set 1 | ascension
# Processing Record 293 of Set 1 | ferrol
# Processing Record 294 of Set 1 | gizo
# Processing Record 295 of Set 1 | khromtau
# Processing Record 296 of Set 1 | pozhva
# City not found... skipping.
# Processing Record 297 of Set 1 | radcliff
# Processing Record 298 of Set 1 | zhigansk
# Processing Record 299 of Set 1 | kaeo
# Processing Record 300 of Set 1 | karratha
# Processing Record 301 of Set 1 | mount isa
# Processing Record 302 of Set 1 | abha
# Processing Record 303 of Set 1 | kolondieba
# Processing Record 304 of Set 1 | udachnyy
# Processing Record 305 of Set 1 | wattegama
# Processing Record 306 of Set 1 | haradok
# Processing Record 307 of Set 1 | kedrovyy
# Processing Record 308 of Set 1 | junin
# Processing Record 309 of Set 1 | nezlobnaya
# Processing Record 310 of Set 1 | ponta do sol
# Processing Record 311 of Set 1 | ostersund
# Processing Record 312 of Set 1 | mayo
# Processing Record 313 of Set 1 | maracas
# Processing Record 314 of Set 1 | vanavara
# Processing Record 315 of Set 1 | kalmunai
# Processing Record 316 of Set 1 | grants
# City not found... skipping.
# Processing Record 317 of Set 1 | ulladulla
# Processing Record 318 of Set 1 | trelew
# Processing Record 319 of Set 1 | honningsvag
# Processing Record 320 of Set 1 | dwarka
# Processing Record 321 of Set 1 | coolum beach
# Processing Record 322 of Set 1 | basse-pointe
# Processing Record 323 of Set 1 | yar-sale
# Processing Record 324 of Set 1 | vila velha
# Processing Record 325 of Set 1 | pacific grove
# Processing Record 326 of Set 1 | bonthe
# Processing Record 327 of Set 1 | hobyo
# Processing Record 328 of Set 1 | jinka
# Processing Record 329 of Set 1 | dalvik
# Processing Record 330 of Set 1 | prince george
# Processing Record 331 of Set 1 | talara
# Processing Record 332 of Set 1 | lorengau
# Processing Record 333 of Set 1 | bonavista
# Processing Record 334 of Set 1 | goya
# Processing Record 335 of Set 1 | acarau
# Processing Record 336 of Set 1 | morondava
# Processing Record 337 of Set 1 | havoysund
# Processing Record 338 of Set 1 | barrow
# City not found... skipping.
# City not found... skipping.
# Processing Record 339 of Set 1 | rafai
# Processing Record 340 of Set 1 | kirakira
# Processing Record 341 of Set 1 | maceio
# Processing Record 342 of Set 1 | kaka
# Processing Record 343 of Set 1 | garowe
# Processing Record 344 of Set 1 | micheweni
# Processing Record 345 of Set 1 | nouadhibou
# Processing Record 346 of Set 1 | srednekolymsk
# Processing Record 347 of Set 1 | kutum
# Processing Record 348 of Set 1 | carnarvon
# Processing Record 349 of Set 1 | penzance
# Processing Record 350 of Set 1 | chunskiy
# Processing Record 351 of Set 1 | sweetwater
# Processing Record 352 of Set 1 | taoudenni
# Processing Record 353 of Set 1 | morant bay
# Processing Record 354 of Set 1 | margate
# Processing Record 355 of Set 1 | port-gentil
# Processing Record 356 of Set 1 | mazamari
# Processing Record 357 of Set 1 | goderich
# Processing Record 358 of Set 1 | murdochville
# City not found... skipping.
# Processing Record 359 of Set 1 | bintulu
# Processing Record 360 of Set 1 | bystrice nad pernstejnem
# Processing Record 361 of Set 1 | gat
# Processing Record 362 of Set 1 | teya
# Processing Record 363 of Set 1 | bulawayo
# City not found... skipping.
# Processing Record 364 of Set 1 | nanortalik
# Processing Record 365 of Set 1 | clarence town
# City not found... skipping.
# Processing Record 366 of Set 1 | bend
# Processing Record 367 of Set 1 | puerto leguizamo
# Processing Record 368 of Set 1 | lagoa
# Processing Record 369 of Set 1 | tongliao
# Processing Record 370 of Set 1 | malanje
# Processing Record 371 of Set 1 | karasjok
# Processing Record 372 of Set 1 | buala
# Processing Record 373 of Set 1 | daru
# Processing Record 374 of Set 1 | oum hadjer
# City not found... skipping.
# Processing Record 375 of Set 1 | komsomolskiy
# Processing Record 376 of Set 1 | dikson
# Processing Record 377 of Set 1 | aswan
# Processing Record 378 of Set 1 | sorland
# City not found... skipping.
# Processing Record 379 of Set 1 | zholymbet
# Processing Record 380 of Set 1 | aksarka
# Processing Record 381 of Set 1 | george town
# Processing Record 382 of Set 1 | beaufort
# Processing Record 383 of Set 1 | porto novo
# Processing Record 384 of Set 1 | vestmanna
# Processing Record 385 of Set 1 | the valley
# Processing Record 386 of Set 1 | saint-francois
# Processing Record 387 of Set 1 | hof
# Processing Record 388 of Set 1 | qasigiannguit
# Processing Record 389 of Set 1 | hami
# Processing Record 390 of Set 1 | seymchan
# Processing Record 391 of Set 1 | leh
# Processing Record 392 of Set 1 | otorohanga
# Processing Record 393 of Set 1 | nyimba
# Processing Record 394 of Set 1 | boende
# Processing Record 395 of Set 1 | katobu
# Processing Record 396 of Set 1 | tromso
# Processing Record 397 of Set 1 | sobolevo
# Processing Record 398 of Set 1 | vostok
# Processing Record 399 of Set 1 | suf
# Processing Record 400 of Set 1 | wewak
# Processing Record 401 of Set 1 | guadalajara
# Processing Record 402 of Set 1 | okhotsk
# Processing Record 403 of Set 1 | westport
# Processing Record 404 of Set 1 | netivot
# Processing Record 405 of Set 1 | novikovo
# Processing Record 406 of Set 1 | kanigoro
# Processing Record 407 of Set 1 | mezhdurechensk
# Processing Record 408 of Set 1 | santiago de cao
# City not found... skipping.
# Processing Record 409 of Set 1 | palmeira das missoes
# Processing Record 410 of Set 1 | mago
# Processing Record 411 of Set 1 | pringsewu
# Processing Record 412 of Set 1 | amapa
# Processing Record 413 of Set 1 | buraydah
# Processing Record 414 of Set 1 | bac lieu
# Processing Record 415 of Set 1 | ashland
# Processing Record 416 of Set 1 | arica
# Processing Record 417 of Set 1 | aitape
# Processing Record 418 of Set 1 | beringovskiy
# Processing Record 419 of Set 1 | honiara
# Processing Record 420 of Set 1 | vredendal
# Processing Record 421 of Set 1 | partenit
# Processing Record 422 of Set 1 | omaruru
# Processing Record 423 of Set 1 | olafsvik
# Processing Record 424 of Set 1 | nizwa
# Processing Record 425 of Set 1 | ponta delgada
# Processing Record 426 of Set 1 | snasa
# Processing Record 427 of Set 1 | conakry
# Processing Record 428 of Set 1 | mount gambier
# Processing Record 429 of Set 1 | cayenne
# Processing Record 430 of Set 1 | vangaindrano
# Processing Record 431 of Set 1 | mangrol
# Processing Record 432 of Set 1 | cap malheureux
# City not found... skipping.
# Processing Record 433 of Set 1 | sarangani
# Processing Record 434 of Set 1 | klaksvik
# Processing Record 435 of Set 1 | waingapu
# Processing Record 436 of Set 1 | ballina
# Processing Record 437 of Set 1 | pauini
# Processing Record 438 of Set 1 | santa lucia
# Processing Record 439 of Set 1 | merauke
# Processing Record 440 of Set 1 | korla
# City not found... skipping.
# Processing Record 441 of Set 1 | half moon bay
# City not found... skipping.
# Processing Record 442 of Set 1 | pietarsaari
# City not found... skipping.
# Processing Record 443 of Set 1 | luderitz
# Processing Record 444 of Set 1 | bara
# Processing Record 445 of Set 1 | chillicothe
# Processing Record 446 of Set 1 | malakal
# Processing Record 447 of Set 1 | nagamangala
# Processing Record 448 of Set 1 | kaarina
# Processing Record 449 of Set 1 | hay river
# Processing Record 450 of Set 1 | varena
# City not found... skipping.
# Processing Record 451 of Set 1 | harrisonville
# Processing Record 452 of Set 1 | savantvadi
# Processing Record 453 of Set 1 | retz
# Processing Record 454 of Set 1 | selenice
# Processing Record 455 of Set 1 | marsh harbour
# Processing Record 456 of Set 1 | ixtapa
# Processing Record 457 of Set 1 | melo
# Processing Record 458 of Set 1 | pierre
# Processing Record 459 of Set 1 | serenje
# Processing Record 460 of Set 1 | samana
# Processing Record 461 of Set 1 | puerto del rosario
# Processing Record 462 of Set 1 | presidencia roque saenz pena
# City not found... skipping.
# City not found... skipping.
# Processing Record 463 of Set 1 | ust-omchug
# Processing Record 464 of Set 1 | koungheul
# City not found... skipping.
# Processing Record 465 of Set 1 | pangnirtung
# Processing Record 466 of Set 1 | sebinkarahisar
# Processing Record 467 of Set 1 | ambanja
# Processing Record 468 of Set 1 | ryde
# Processing Record 469 of Set 1 | kaifeng
# Processing Record 470 of Set 1 | katsuura
# Processing Record 471 of Set 1 | tateyama
# Processing Record 472 of Set 1 | bokoro
# Processing Record 473 of Set 1 | zhangye
# Processing Record 474 of Set 1 | umm lajj
# Processing Record 475 of Set 1 | egvekinot
# Processing Record 476 of Set 1 | sheltozero
# Processing Record 477 of Set 1 | sibu
# Processing Record 478 of Set 1 | igboho
# Processing Record 479 of Set 1 | malindi
# Processing Record 480 of Set 1 | concordia
# Processing Record 481 of Set 1 | jiuquan
# Processing Record 482 of Set 1 | svetlyy
# Processing Record 483 of Set 1 | timmins
# Processing Record 484 of Set 1 | tarragona
# Processing Record 485 of Set 1 | ilovlya
# Processing Record 486 of Set 1 | olot
# Processing Record 487 of Set 1 | neijiang
# Processing Record 488 of Set 1 | manokwari
# Processing Record 489 of Set 1 | batticaloa
# Processing Record 490 of Set 1 | dublin
# Processing Record 491 of Set 1 | manta
# Processing Record 492 of Set 1 | camopi
# Processing Record 493 of Set 1 | labuhan
# Processing Record 494 of Set 1 | riyadh
# Processing Record 495 of Set 1 | saint-dizier
# Processing Record 496 of Set 1 | hualmay
# Processing Record 497 of Set 1 | gorin
# Processing Record 498 of Set 1 | xichang
# Processing Record 499 of Set 1 | concepcion del oro
# Processing Record 500 of Set 1 | lompoc
# Processing Record 501 of Set 1 | nuuk
# Processing Record 502 of Set 1 | ornskoldsvik
# Processing Record 503 of Set 1 | narsipatnam
# Processing Record 504 of Set 1 | barbosa ferraz
# Processing Record 505 of Set 1 | evensk
# Processing Record 506 of Set 1 | aloleng
# Processing Record 507 of Set 1 | alphen
# Processing Record 508 of Set 1 | lasa
# Processing Record 509 of Set 1 | elat
# Processing Record 510 of Set 1 | thinadhoo
# Processing Record 511 of Set 1 | petrovsk-zabaykalskiy
# Processing Record 512 of Set 1 | maamba
# Processing Record 513 of Set 1 | moron
# Processing Record 514 of Set 1 | palmares do sul
# Processing Record 515 of Set 1 | olga
# Processing Record 516 of Set 1 | anadyr
# Processing Record 517 of Set 1 | dosso
# Processing Record 518 of Set 1 | lake havasu city
# Processing Record 519 of Set 1 | waitati
# Processing Record 520 of Set 1 | sisimiut
# Processing Record 521 of Set 1 | oranjemund
# Processing Record 522 of Set 1 | larap
# Processing Record 523 of Set 1 | cangzhou
# Processing Record 524 of Set 1 | fare
# Processing Record 525 of Set 1 | tungor
# Processing Record 526 of Set 1 | atherton
# Processing Record 527 of Set 1 | anori
# Processing Record 528 of Set 1 | bar harbor
# Processing Record 529 of Set 1 | ahuimanu
# Processing Record 530 of Set 1 | savannah bight
# Processing Record 531 of Set 1 | sungaipenuh
# Processing Record 532 of Set 1 | namatanai
# Processing Record 533 of Set 1 | hofn
# Processing Record 534 of Set 1 | alta floresta
# Processing Record 535 of Set 1 | codrington
# Processing Record 536 of Set 1 | banda aceh
# Processing Record 537 of Set 1 | andra
# Processing Record 538 of Set 1 | kraslava
# Processing Record 539 of Set 1 | ishikari
# Processing Record 540 of Set 1 | freeport
# Processing Record 541 of Set 1 | tonneins
# Processing Record 542 of Set 1 | sirvintos
# Processing Record 543 of Set 1 | valparaiso
# Processing Record 544 of Set 1 | recodo
# Processing Record 545 of Set 1 | suvorovo
# City not found... skipping.
# Processing Record 546 of Set 1 | kapit
# City not found... skipping.
# Processing Record 547 of Set 1 | dayong
# Processing Record 548 of Set 1 | devils lake
# Processing Record 549 of Set 1 | siwan
# Processing Record 550 of Set 1 | karpathos
# Processing Record 551 of Set 1 | ewo
# Processing Record 552 of Set 1 | karasburg
# Processing Record 553 of Set 1 | asfi
# Processing Record 554 of Set 1 | avelgem
# Processing Record 555 of Set 1 | elk point
# Processing Record 556 of Set 1 | kulhudhuffushi
# Processing Record 557 of Set 1 | kalemie
# Processing Record 558 of Set 1 | solnechnyy
# Processing Record 559 of Set 1 | lakselv
# Processing Record 560 of Set 1 | tabriz
# Processing Record 561 of Set 1 | cankuzo
# Processing Record 562 of Set 1 | port hedland
# Processing Record 563 of Set 1 | arroyo
# Processing Record 564 of Set 1 | west bay
# Processing Record 565 of Set 1 | ossora
# Processing Record 566 of Set 1 | opuwo
# City not found... skipping.
# Processing Record 567 of Set 1 | manzanillo
# Processing Record 568 of Set 1 | mende
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# City not found... skipping.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 12>()
#      17  queryURL = f"{url}appid={api_key}&units={units}&q={city}"
#      18 # print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
#      19 # record_count+=1
# ---> 20  time.sleep(1)
#      21  try:
#      22      weatherResponse = requests.get(queryURL)
#
# KeyboardInterrupt:

# %%
units = "imperial"
latitudes = []
longitudes = []
maxtempFs = []
humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
date = []


#loop through the cities and grab the information needed for the cities

for city in cities:
    queryURL = f"{url}appid={api_key}&units={units}&q={city}"
    #get weather data
    weatherResponse = requests.get(queryURL)
    weatherJSON = weatherResponse.json()
    
#how do we find max temps inside json?


    #add the info to the lists
    maxtempFs.append(weatherJSON['main']['temp'])
    latitudes.append(weatherJSON['coord']['lat'])
    longitudes.append(weatherJSON['coord']['lon'])
    
    humidity.append(weatherJSON['coord']['lon']) # change the attributes
    Cloudiness.append(weatherJSON['coord']['lon'])# change the attributes
    Wind_Speed.append(weatherJSON['coord']['lon'])# change the attributes
    Country.append(weatherJSON['coord']['lon'])# change the attributes
    date.append(weatherJSON['coord']['lon'])# change the attributes
    
    
    
    
print(tempFs)
print(latitudes)
print(longitudes) 
print()
print()
print()
print()
print()

# %%
cities_df = pd.DataFrame(cities)
cities_df

# %%
cities_df.to_csv("resources/weatherdata.csv")

# %%
cities_df=pd.read_csv("")

# %%
#use the info in the lists and make a dataframe

weatherDictionary = {
    
    "City" : cities,
    "Temperature" : tempFs,
    "Latitude" : latitudes,
    "longitude" :longitudes
 }

weatherDF =pd.DataFrame(weatherDictionary)
weatherDF

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
